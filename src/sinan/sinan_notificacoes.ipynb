# %% [markdown]
# # Notificações Dengue via SINAN
#
# Ministério da Saúde.
# Sistema de Informação de Agravos de Notificação (SINAN).
# Notificações Dengue.
# Disponível em: [basedados.org](https://basedosdados.org/dataset/f51134c2-5ab9-4bbc-882f-f1034603147a?table=9bdbca38-d97f-47fa-b422-84477a6b68c8)

# %% [markdown]
# # **1. Python Libraries**

# %% [markdown]
# ## **1.1 Conect to BQ**

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
# %load_ext google.colab.data_table
#%unload_ext google.colab.data_table

# %%
from google.cloud import bigquery
from google.colab import syntax

project_id=	'barnabe-bq'

# %% [markdown]
# ## **1.1.1 Testando a conexão**

# %%
# %%bigquery query --project {project_id}
#
# SELECT
#         chave AS chave_tipo_notificacao,
#         valor AS descricao_tipo_notificacao
#     FROM `basedosdados.br_ms_sinan.dicionario`
#     WHERE
#         TRUE
#         AND nome_coluna = 'tipo_notificacao'
#         AND id_tabela = 'microdados_dengue'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
query.head()
# Out:
#   chave_tipo_notificacao descricao_tipo_notificacao
# 0                      4                   Agregado
# 1                      2                 Individual
# 2                      1                   Negativa
# 3                      3                      Surto

# %% [markdown]
# # Dataset Analitico

# %%
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
# prompt: salvar o df criado na area de trabalho

from google.colab import files
df.to_csv('dengue_df.csv', encoding = 'utf-8-sig')
files.download('dengue_df.csv')
